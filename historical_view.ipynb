# %%
# Import all the necessary libraries

import numpy as np
import pandas as pd
from datetime import datetime as dt
import itertools

# %matplotlib inline

# %%
# Read data from the CSV into a dataframe

loc = "./Datasets/"

#raw_data_1 = pd.read_csv(loc + '2000-01.csv')
#raw_data_2 = pd.read_csv(loc + '2001-02.csv')
#raw_data_3 = pd.read_csv(loc + '2002-03.csv')
#raw_data_4 = pd.read_csv(loc + '2003-04.csv')
#raw_data_5 = pd.read_csv(loc + '2004-05.csv')
#raw_data_6 = pd.read_csv(loc + '2005-06.csv')
#raw_data_7 = pd.read_csv(loc + '2006-07.csv')
#raw_data_8 = pd.read_csv(loc + '2007-08.csv')
#raw_data_9 = pd.read_csv(loc + '2008-09.csv')
#raw_data_10 = pd.read_csv(loc + '2009-10.csv')
#raw_data_11 = pd.read_csv(loc + '2010-11.csv')
#raw_data_12 = pd.read_csv(loc + '2011-12.csv')
#raw_data_13 = pd.read_csv(loc + '2012-13.csv')
#raw_data_14 = pd.read_csv(loc + '2013-14.csv')
#raw_data_15 = pd.read_csv(loc + '2014-15.csv')
#raw_data_16 = pd.read_csv(loc + '2015-16.csv')
raw_data_17 = pd.read_csv(loc + 'D1_Buli_1617.csv')
raw_data_18 = pd.read_csv(loc + 'D1_Buli_1718.csv')

# %%
raw_data_18
# Out:
#     Div      Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    D1  18/08/17  Bayern Munich     Leverkusen     3     1   H     2     0
# 1    D1  19/08/17        Hamburg       Augsburg     1     0   H     1     0
# 2    D1  19/08/17         Hertha      Stuttgart     2     0   H     0     0
# 3    D1  19/08/17     Hoffenheim  Werder Bremen     1     0   H     0     0
# 4    D1  19/08/17          Mainz       Hannover     0     1   A     0     0
# 5    D1  19/08/17     Schalke 04     RB Leipzig     2     0   H     1     0
# 6    D1  19/08/17      Wolfsburg       Dortmund     0     3   A     0     2
# 7    D1  20/08/17       Freiburg  Ein Frankfurt     0     0   D     0     0
# 8    D1  20/08/17     M'gladbach        FC Koln     1     0   H     0     0
# 9    D1  25/08/17        FC Koln        Hamburg     1     3   A     0     2
# 10   D1  26/08/17       Augsburg     M'gladbach     2     2   D     1     2
# 11   D1  26/08/17       Dortmund         Hertha     2     0   H     1     0
# 12   D1  26/08/17  Ein Frankfurt      Wolfsburg     0     1   A     0     1
# 13   D1  26/08/17     Leverkusen     Hoffenheim     2     2   D     1     0
# 14   D1  26/08/17      Stuttgart          Mainz     1     0   H     0     0
# 15   D1  26/08/17  Werder Bremen  Bayern Munich     0     2   A     0     0
# 16   D1  27/08/17       Hannover     Schalke 04     1     0   H     0     0
# 17   D1  27/08/17     RB Leipzig       Freiburg     4     1   H     0     1
# 18   D1  08/09/17        Hamburg     RB Leipzig     0     2   A     0     0
# 19   D1  09/09/17       Augsburg        FC Koln     3     0   H     2     0
# 20   D1  09/09/17       Freiburg       Dortmund     0     0   D     0     0
# 21   D1  09/09/17     Hoffenheim  Bayern Munich     2     0   H     1     0
# 22   D1  09/09/17          Mainz     Leverkusen     3     1   H     1     1
# 23   D1  09/09/17     M'gladbach  Ein Frankfurt     0     1   A     0     1
# 24   D1  09/09/17      Wolfsburg       Hannover     1     1   D     0     0
# 25   D1  10/09/17         Hertha  Werder Bremen     1     1   D     1     0
# 26   D1  10/09/17     Schalke 04      Stuttgart     3     1   H     1     1
# 27   D1  15/09/17       Hannover        Hamburg     2     0   H     0     0
# 28   D1  16/09/17  Bayern Munich          Mainz     4     0   H     2     0
# 29   D1  16/09/17  Ein Frankfurt       Augsburg     1     2   A     0     1
# ..   ..       ...            ...            ...   ...   ...  ..   ...   ...
# 258  D1  08/04/18       Dortmund      Stuttgart     3     0   H     1     0
# 259  D1  08/04/18  Ein Frankfurt     Hoffenheim     1     1   D     0     0
# 260  D1  09/04/18     RB Leipzig     Leverkusen     1     4   A     1     1
# 261  D1  13/04/18      Wolfsburg       Augsburg     0     0   D     0     0
# 262  D1  14/04/18  Bayern Munich     M'gladbach     5     1   H     2     1
# 263  D1  14/04/18         Hertha        FC Koln     2     1   H     0     1
# 264  D1  14/04/18     Hoffenheim        Hamburg     2     0   H     2     0
# 265  D1  14/04/18     Leverkusen  Ein Frankfurt     4     1   H     1     1
# 266  D1  14/04/18      Stuttgart       Hannover     1     1   D     0     0
# 267  D1  15/04/18     Schalke 04       Dortmund     2     0   H     0     0
# 268  D1  15/04/18  Werder Bremen     RB Leipzig     1     1   D     1     0
# 269  D1  16/04/18          Mainz       Freiburg     2     0   H     1     0
# 270  D1  20/04/18     M'gladbach      Wolfsburg     3     0   H     3     0
# 271  D1  21/04/18       Dortmund     Leverkusen     4     0   H     1     0
# 272  D1  21/04/18  Ein Frankfurt         Hertha     0     3   A     0     0
# 273  D1  21/04/18        Hamburg       Freiburg     1     0   H     0     0
# 274  D1  21/04/18       Hannover  Bayern Munich     0     3   A     0     0
# 275  D1  21/04/18     RB Leipzig     Hoffenheim     2     5   A     0     3
# 276  D1  21/04/18      Stuttgart  Werder Bremen     2     0   H     1     0
# 277  D1  22/04/18       Augsburg          Mainz     2     0   H     1     0
# 278  D1  22/04/18        FC Koln     Schalke 04     2     2   D     1     2
# 279  D1  27/04/18     Hoffenheim       Hannover     3     1   H     1     1
# 280  D1  28/04/18  Bayern Munich  Ein Frankfurt     4     1   H     1     0
# 281  D1  28/04/18       Freiburg        FC Koln     3     2   H     1     0
# 282  D1  28/04/18         Hertha       Augsburg     2     2   D     0     1
# 283  D1  28/04/18     Leverkusen      Stuttgart     0     1   A     0     0
# 284  D1  28/04/18     Schalke 04     M'gladbach     1     1   D     1     1
# 285  D1  28/04/18      Wolfsburg        Hamburg     1     3   A     0     2
# 286  D1  29/04/18          Mainz     RB Leipzig     3     0   H     1     0
# 287  D1  29/04/18  Werder Bremen       Dortmund     1     1   D     1     1
#
#     HTR  ...    BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
# 0     H  ...        2.88    17  -2.00     2.26     2.18     1.77     1.72
# 1     H  ...        1.68    18  -0.25     1.88     1.84     2.07     2.03
# 2     D  ...        1.87    18  -0.50     2.09     2.05     1.87     1.83
# 3     D  ...        2.50    16  -0.75     2.04     1.98     1.91     1.88
# 275   A  ...        2.86    20  -0.25     1.84     1.76     2.76     2.13
# 276   H  ...        1.80    19  -0.25     2.14     2.08     1.83     1.79
# 277   H  ...        1.69    18  -0.25     1.99     1.93     1.96     1.92
# 278   A  ...        1.95    17   0.50     1.93     1.89     2.01     1.97
# 279   D  ...        3.18    20  -1.75     1.99     1.94     1.96     1.91
# 280   H  ...        2.24    21  -0.75     1.83     1.79     2.15     2.08
# 281   H  ...        1.77    19  -0.25     1.86     1.82     2.08     2.03
# 282   A  ...        1.80    21  -0.25     1.86     1.81     2.12     2.05
# 283   D  ...        2.44    20  -1.25     1.94     1.90     2.00     1.96
# 284   D  ...        1.96    20  -0.50     1.88     1.84     2.08     2.02
# 285   A  ...        1.66    22  -0.25     1.97     1.92     2.01     1.94
# 286   H  ...        2.00    20   0.25     2.10     2.05     1.86     1.82
# 287   D  ...        2.38    19   0.50     1.96     1.92     2.00     1.94
#
#       PSCH  PSCD   PSCA
# 0     1.28  6.70  11.30
# 1     2.32  3.32   3.47
# 2     2.02  3.60   4.07
# 3     1.85  4.19   4.12
# 4     1.85  3.75   4.65
# 5     2.85  3.48   2.62
# 6     4.07  3.81   1.95
# 7     2.94  3.17   2.74
# 8     1.80  3.85   4.89
# 9     2.04  3.47   4.11
# 10    3.46  3.44   2.27
# 11    1.41  5.24   8.40
# 12    2.23  3.35   3.65
# 13    1.97  4.06   3.75
# 14    2.47  3.56   2.99
# 15   13.11  7.11   1.25
# 16    3.11  3.39   2.47
# 17    1.38  5.17   9.82
# 18    4.26  3.98   1.87
# 19    2.25  3.47   3.49
# 20    9.97  5.95   1.33
# 21    6.95  5.04   1.47
# 22    3.51  3.68   2.16
# 23    1.98  3.61   4.19
# 24    1.86  3.73   4.64
# 25    2.15  3.51   3.70
# 26    1.79  3.84   5.00
# 27    1.96  3.63   4.24
# 28    1.17  8.59  19.37
# 29    1.91  3.55   4.63
# ..     ...   ...    ...
# 258   1.52  4.66   6.50
# 259   2.33  3.69   3.08
# 260   2.18  3.85   3.25
# 261   2.26  3.26   3.63
# 262   1.35  5.63   9.26
# 263   1.82  3.93   4.51
# 264   1.52  4.80   6.26
# 265   1.70  4.04   5.29
# 266   1.79  3.90   4.75
# 267   3.14  3.43   2.41
# 268   2.66  3.64   2.67
# 269   2.15  3.27   3.94
# 270   1.72  4.03   5.06
# 271   2.16  3.74   3.40
# 272   1.97  3.52   4.29
# 273   2.07  3.49   3.91
# 274   7.52  5.20   1.43
# 275   2.36  3.89   2.90
# 276   2.50  3.40   3.02
# 277   2.36  3.31   3.34
# 278   3.67  3.44   2.16
# 279   1.30  6.44  10.00
# 280   2.09  3.53   3.79
# 281   2.13  3.56   3.65
# 282   2.09  3.54   3.79
# 283   1.45  5.07   7.28
# 284   1.89  3.85   4.24
# 285   2.35  3.44   3.24
# 286   3.51  3.75   2.11
# 287   4.11  3.94   1.89
#
# [288 rows x 64 columns]

# %%
# Parse data as time

def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%d/%m/%Y').date()
    
def parse_date_other(date):
    if date == '':
        return None
    else: 
        return dt.strptime(date, '%d/%m/%Y').date()
    
    

#raw_data_17.Date = raw_data_17.Date.apply(parse_date)
#raw_data_18.Date = raw_data_18.Date.apply(parse_date)



#Gets all the statistics related to draw betting strategy

columns_req = ['Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365D', 
              'BWD', 'IWD', 'LBD', 'PSD', 'VCD', 'WHD', 'PSCD']

odds_statistics_17 = raw_data_17[columns_req]
odds_statistics_18 = raw_data_18[columns_req]

# %%
odds_statistics_17
# Out:
#          Date       HomeTeam       AwayTeam FTR  B365D    BWD    IWD    LBD  \
# 0    26/08/16  Bayern Munich  Werder Bremen   H  10.00   9.75   7.00  10.00
# 1    27/08/16       Augsburg      Wolfsburg   A   3.25   3.40   3.20   3.30
# 2    27/08/16       Dortmund          Mainz   H   5.00   4.60   4.40   5.00
# 3    27/08/16  Ein Frankfurt     Schalke 04   H   3.30   3.50   3.30   3.40
# 4    27/08/16        FC Koln      Darmstadt   H   3.50   3.50   3.50   3.50
# 5    27/08/16        Hamburg     Ingolstadt   D   3.20   3.20   3.30   3.10
# 6    27/08/16     M'gladbach     Leverkusen   H   3.40   3.40   3.20   3.40
# 7    28/08/16         Hertha       Freiburg   H   3.30   3.30   3.20   3.20
# 8    28/08/16     Hoffenheim     RB Leipzig   D   3.25   3.10   3.20   3.30
# 9    09/09/16     Schalke 04  Bayern Munich   A   5.50   5.75   5.00   5.25
# 10   10/09/16      Darmstadt  Ein Frankfurt   H   3.30   3.30   3.20   3.25
# 11   10/09/16       Freiburg     M'gladbach   H   3.60   3.60   3.40   3.60
# 12   10/09/16     Ingolstadt         Hertha   A   3.10   3.10   3.20   3.00
# 13   10/09/16     Leverkusen        Hamburg   H   4.50   4.33   4.00   4.33
# 14   10/09/16     RB Leipzig       Dortmund   H   4.20   4.25   4.00   4.20
# 15   10/09/16      Wolfsburg        FC Koln   D   3.75   3.70   3.60   3.60
# 16   11/09/16          Mainz     Hoffenheim   D   3.50   3.60   3.40   3.50
# 17   11/09/16  Werder Bremen       Augsburg   A   3.40   3.40   3.30   3.40
# 18   16/09/16        FC Koln       Freiburg   H   3.60   3.75   3.50   3.50
# 19   17/09/16  Bayern Munich     Ingolstadt   H  12.00  10.50  11.00  11.00
# 20   17/09/16       Dortmund      Darmstadt   H   9.00   7.75   7.50   9.00
# 21   17/09/16  Ein Frankfurt     Leverkusen   H   3.50   3.60   3.50   3.50
# 22   17/09/16        Hamburg     RB Leipzig   A   3.25   3.20   3.30   3.25
# 23   17/09/16     Hoffenheim      Wolfsburg   D   3.60   3.40   3.30   3.50
# 24   17/09/16     M'gladbach  Werder Bremen   H   4.50   4.40   4.20   4.50
# 25   18/09/16       Augsburg          Mainz   A   3.40   3.50   3.35   3.30
# 26   18/09/16         Hertha     Schalke 04   H   3.40   3.40   3.30   3.10
# 27   20/09/16      Darmstadt     Hoffenheim   D   3.50   3.40   3.40   3.60
# 28   20/09/16       Freiburg        Hamburg   H   3.40   3.40   3.30   3.30
# 29   20/09/16     Ingolstadt  Ein Frankfurt   A   3.25   3.25   3.30   3.20
# 13    4.65   4.60   4.20   4.43
# 14    4.36   4.40   3.60   4.42
# 15    3.80   3.80   3.40   3.88
# 16    3.69   3.75   3.40   3.73
# 17    3.57   3.50   3.30   3.52
# 18    3.77   3.80   3.60   3.96
# 19   12.80  13.00   8.00   8.99
# 20    9.90   9.00   8.00   8.53
# 21    3.66   3.60   3.10   3.77
# 22    3.31   3.30   3.10   3.41
# 23    3.63   3.60   3.40   3.73
# 24    5.00   5.00   4.00   5.15
# 25    3.47   3.50   3.10   3.39
# 26    3.31   3.40   3.10   3.41
# 27    3.70   3.70   3.40   3.91
# 28    3.52   3.50   3.30   3.49
# 29    3.36   3.30    NaN   3.49
# ..     ...    ...    ...    ...
# 276   5.01   5.00   4.80   5.43
# 277   3.35   3.30   3.20   3.30
# 278   4.46   4.20   4.20   4.72
# 279   3.65   3.60   3.60   3.56
# 280  13.00  15.00  10.00  14.60
# 281   5.11   4.80   4.75   5.00
# 282   3.48   3.40   3.10   3.64
# 283   3.48   3.50   3.30   3.61
# 284   3.61   3.50   3.40   3.54
# 285   4.03   3.90   3.80   3.81
# 286   3.71   3.50   3.40   3.65
# 287   3.55   3.40   3.40   3.42
# 288   4.86   4.75   4.50   5.64
# 289   3.55   3.40   3.30   3.57
# 290   3.68   3.50   3.40   3.65
# 291   3.71   3.50   3.30   3.37
# 292   3.91   3.80   3.60   3.60
# 293   3.92   3.75   3.75   4.51
# 294   3.82   3.75   3.40   4.04
# 295   3.89   3.75   3.60   4.22
# 296   3.90   3.75   3.75   3.82
# 297   8.70   8.00   7.00   9.54
# 298   8.38   7.50   7.50   9.55
# 299   3.93   3.75   3.75   3.50
# 300   4.24   4.20   4.33   5.11
# 301   3.50   3.25   3.30   3.48
# 302   3.66   3.50   3.40   3.68
# 303   5.68   5.50   5.50   5.09
# 304   3.77   3.50   3.40   3.78
# 305   5.86   5.00   5.00   7.23
#
# [306 rows x 12 columns]

# %%
draws_17 = odds_statistics_17.loc[odds_statistics_17['FTR'] == 'D']
draws_18 = odds_statistics_18.loc[odds_statistics_18['FTR'] == 'D']

blacklist = ['Bayern Munich']

draws_17_wo_bayern = draws_17.loc[~draws_17['HomeTeam'].isin(blacklist)]
draws_18_wo_bayern = draws_18.loc[~draws_18['HomeTeam'].isin(blacklist)]

print(len(draws_17))
print(len(draws_17_wo_bayern))

print(len(draws_18))
print(len(draws_18_wo_bayern))
# Out:
# 74
# 70
# 82
# 80

# %%
# average odd b365
b365D_odd_18 = draws_18['B365D'].sum()
b365D_odd_17 = draws_17['B365D'].sum()

b365D_odd_18_wo = draws_18_wo_bayern['B365D'].sum()
b365D_odd_17_wo = draws_17_wo_bayern['B365D'].sum()


print("2018")
print("-----")
print("odds B365:")
print("all: " + str(b365D_odd_18))
print("wo : " + str(b365D_odd_18_wo))
print("n of Draws:")
print("all: " + str(len(draws_18)))
print("wo : " + str(len(draws_18_wo_bayern)))
print("result:")
print("all: " + str(b365D_odd_18-34*9))
print("wo : " + str(b365D_odd_18_wo-34*8))
#print("n in p :" + str(int(len(draws_1834*9/100))))
print("\n#####################################\n")
print("2017")
print("-----")
print("odds B365:")
print("all: " + str(b365D_odd_17))
print("wo : " + str(b365D_odd_17_wo))
print("n of Draws:")
print("all: " + str(len(draws_17)))
print("wo : " + str(len(draws_17_wo_bayern)))
print("result:")
print("all: " + str(b365D_odd_17-34*9))
print("wo : " + str(b365D_odd_17_wo-34*8))
# Out:
# 2018
# -----
# odds B365:
# all: 306.89
# wo : 290.89
# n of Draws:
# all: 82
# wo : 80
# result:
# all: 0.8899999999999864
# wo : 18.889999999999986
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1201         try:
# -> 1202             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1203         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1376             with np.errstate(all='ignore'):
# -> 1377                 result = get_result(other)
#    1378
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get_result(other)
#    1345             else:
# -> 1346                 result = func(values, other)
#    1347
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1227                     with np.errstate(all='ignore'):
# -> 1228                         result[mask] = op(xrav, y)
#    1229             else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-0a842c302252> in <module>()
#      18 print("all: " + str(b365D_odd_18-34*9))
#      19 print("wo : " + str(b365D_odd_18_wo-34*8))
# ---> 20 print("n in p :" + str(int(len(draws_18/34*9/100))))
#      21 print("\n#####################################\n")
#      22 print("2017")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1265                 self = self.fillna(fill_value)
#    1266
# -> 1267             return self._combine_const(other, na_op)
#    1268
#    1269     f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _combine_const(self, other, func, errors, try_cast)
#    3985         new_data = self._data.eval(func=func, other=other,
#    3986                                    errors=errors,
# -> 3987                                    try_cast=try_cast)
#    3988         return self._constructor(new_data)
#    3989
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, **kwargs)
#    3433
#    3434     def eval(self, **kwargs):
# -> 3435         return self.apply('eval', **kwargs)
#    3436
#    3437     def quantile(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1382             raise
#    1383         except Exception as detail:
# -> 1384             result = handle_error()
#    1385
#    1386         # technically a broadcast error in numpy can 'work' by returning a
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in handle_error()
#    1365                 # The 'detail' variable is defined in outer scope.
#    1366                 raise TypeError('Could not operate %s with block values %s' %
# -> 1367                                 (repr(other), str(detail)))  # noqa
#    1368             else:
#    1369                 # return the values
#
# TypeError: Could not operate 34 with block values unsupported operand type(s) for /: 'str' and 'int'
